# %%
# !pip install pandas numpy scikit-learn matplotlib seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pandas in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (2.3.4)
# Requirement already satisfied: scikit-learn in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (1.7.2)
# Requirement already satisfied: matplotlib in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\pimie\desktop\desarrollo\venvbigdata\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
sns.set_theme(style="whitegrid")

df_spotify_csv = pd.read_csv('../datasets/spotify_data.csv', index_col=0)

# %%
print("----------Info DataFrames----------")
print()
print()
print(df_spotify_csv.info())
print("----------valores nulos en los  DataFrames----------")
print()
print()
print(df_spotify_csv.isnull().sum())
print("----------Mostrar los cinco primeras filas de los DataFrames----------")
print()
print()
print(df_spotify_csv.head(10))
# Out:
# ----------Info DataFrames----------
#
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 1159764 entries, 0 to 1473395
# Data columns (total 19 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   artist_name       1159749 non-null  object
#  1   track_name        1159763 non-null  object
#  2   track_id          1159764 non-null  object
#  3   popularity        1159764 non-null  int64
#  4   year              1159764 non-null  int64
#  5   genre             1159764 non-null  object
#  6   danceability      1159764 non-null  float64
#  7   energy            1159764 non-null  float64
#  8   key               1159764 non-null  int64
#  9   loudness          1159764 non-null  float64
#  10  mode              1159764 non-null  int64
#  11  speechiness       1159764 non-null  float64
#  12  acousticness      1159764 non-null  float64
#  13  instrumentalness  1159764 non-null  float64
#  14  liveness          1159764 non-null  float64
#  15  valence           1159764 non-null  float64
#  16  tempo             1159764 non-null  float64
#  17  duration_ms       1159764 non-null  int64
#  18  time_signature    1159764 non-null  int64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 177.0+ MB
# None
# ----------valores nulos en los  DataFrames----------
#
#
# artist_name         15
# track_name           1
# track_id             0
# popularity           0
# year                 0
# genre                0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# duration_ms          0
# time_signature       0
# dtype: int64
# ----------Mostrar los cinco primeras filas de los DataFrames----------
#
#
#              artist_name                      track_name  \
# 0             Jason Mraz                 I Won't Give Up
# 1             Jason Mraz                93 Million Miles
# 2          Joshua Hyslop                Do Not Let Me Go
# 3           Boyce Avenue                        Fast Car
# 4           Andrew Belle                Sky's Still Blue
# 5          Chris Smither                   What They Say
# 6             Matt Wertz  Walking in a Winter Wonderland
# 7  Green River Ordinance                   Dancing Shoes
# 8             Jason Mraz            Living in the Moment
# 9           Boyce Avenue                          Heaven
#
#                  track_id  popularity  year     genre  danceability  energy  \
# 0  53QF56cjZA9RTuuMZDrSA6          68  2012  acoustic         0.483   0.303
# 1  1s8tP3jP4GZcyHDsjvw218          50  2012  acoustic         0.572   0.454
# 2  7BRCa8MPiyuvr2VU3O9W0F          57  2012  acoustic         0.409   0.234
# 3  63wsZUhUZLlh1OsyrZq7sz          58  2012  acoustic         0.392   0.251
# 4  6nXIYClvJAfi6ujLiKqEq8          54  2012  acoustic         0.430   0.791
# 5  24NvptbNKGs6sPy1Vh1O0v          48  2012  acoustic         0.566   0.570
# 6  0BP7hSvLAG3URGrEvNNbGM          48  2012  acoustic         0.575   0.606
# 7  3Y6BuzQCg9p4yH347Nn8OW          45  2012  acoustic         0.586   0.423
# 8  3ce7k1L4EkZppZPz1EJWTS          44  2012  acoustic         0.650   0.628
# 9  2EKxmYmUdAVXlaHCnnW13o          58  2012  acoustic         0.619   0.280
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    4   -10.058     1       0.0429        0.6940          0.000000    0.1150
# 1    3   -10.286     1       0.0258        0.4770          0.000014    0.0974
# 2    3   -13.711     1       0.0323        0.3380          0.000050    0.0895
# 3   10    -9.845     1       0.0363        0.8070          0.000000    0.0797
# 4    6    -5.419     0       0.0302        0.0726          0.019300    0.1100
# 5    2    -6.420     1       0.0329        0.6880          0.000002    0.0943
# 6    9    -8.197     1       0.0300        0.0119          0.000000    0.0675
# 7    7    -7.459     1       0.0261        0.2520          0.000006    0.0976
# 8    7    -7.160     1       0.0232        0.0483          0.000000    0.1190
# 9    8   -10.238     0       0.0317        0.7300          0.000000    0.1030
#
#    valence    tempo  duration_ms  time_signature
# 0    0.139  133.406       240166               3
# 1    0.515  140.182       216387               4
# 2    0.145  139.832       158960               4
# 3    0.508  204.961       304293               4
# 4    0.217  171.864       244320               4
# 5    0.960   83.403       166240               4
# 6    0.364  121.083       152307               4
# 7    0.318  138.133       232373               4
# 8    0.700   84.141       235080               4
# 9    0.292  129.948       250063               4

# %%
# Boxplots para ver outliers
numerical_cols = df_spotify_csv.select_dtypes(include=np.number).columns

plt.figure(figsize=(15,6))
sns.boxplot(data=df_spotify_csv[numerical_cols])
plt.title("Boxplots de Variables Numéricas")
plt.xticks(rotation=45)
plt.show()


# Gráfico solo para la duración
plt.figure(figsize=(8, 5))
sns.boxplot(data=df_spotify_csv[['duration_ms']])
plt.title('Boxplot de Duración (ms)')
plt.show()

# Gráfico solo para el tempo
plt.figure(figsize=(8, 5))
sns.boxplot(data=df_spotify_csv[['tempo']])
plt.title('Boxplot de Tempo (BPM)')
plt.show()
